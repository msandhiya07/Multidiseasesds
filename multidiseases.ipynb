# %% [markdown]
# <a href="https://colab.research.google.com/github/msandhiya07/Multidiseasesds/blob/main/multidiseases.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Prepocessing data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
kidney_df=pd.read_csv("/content/indian_liver_patient - indian_liver_patient.csv")
kidney_df.head()

# %%
liver_df=pd.read_csv("/content/indian_liver_patient - indian_liver_patient.csv")
liver_df.head()
# Out:
#    Age  Gender  Total_Bilirubin  Direct_Bilirubin  Alkaline_Phosphotase  \
# 0   65  Female              0.7               0.1                   187
# 1   62    Male             10.9               5.5                   699
# 2   62    Male              7.3               4.1                   490
# 3   58    Male              1.0               0.4                   182
# 4   72    Male              3.9               2.0                   195
#
#    Alamine_Aminotransferase  Aspartate_Aminotransferase  Total_Protiens  \
# 0                        16                          18             6.8
# 1                        64                         100             7.5
# 2                        60                          68             7.0
# 3                        14                          20             6.8
# 4                        27                          59             7.3
#
#    Albumin  Albumin_and_Globulin_Ratio  Dataset
# 0      3.3                        0.90        1
# ...

# %%
parkinsons_df=pd.read_csv("/content/parkinsons - parkinsons.csv")
parkinsons_df.head()
# Out:
#              name  MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# 0  phon_R01_S01_1      119.992       157.302        74.997         0.00784
# 1  phon_R01_S01_2      122.400       148.650       113.819         0.00968
# 2  phon_R01_S01_3      116.682       131.111       111.555         0.01050
# 3  phon_R01_S01_4      116.676       137.871       111.366         0.00997
# 4  phon_R01_S01_5      116.014       141.781       110.655         0.01284
#
#    MDVP:Jitter(Abs)  MDVP:RAP  MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  ...  \
# 0           0.00007   0.00370   0.00554     0.01109       0.04374  ...
# 1           0.00008   0.00465   0.00696     0.01394       0.06134  ...
# 2           0.00009   0.00544   0.00781     0.01633       0.05233  ...
# 3           0.00009   0.00502   0.00698     0.01505       0.05492  ...
# 4           0.00011   0.00655   0.00908     0.01966       0.06425  ...
#
#    Shimmer:DDA      NHR     HNR  status      RPDE       DFA   spread1  \
# ...

# %%
# Handle missing values
kidney_df.replace('?', np.nan, inplace=True)
kidney_df.fillna(kidney_df.median(numeric_only=True), inplace=True)
kidney_df.head()
# Out:
#    Age  Gender  Total_Bilirubin  Direct_Bilirubin  Alkaline_Phosphotase  \
# 0   65  Female              0.7               0.1                   187
# 1   62    Male             10.9               5.5                   699
# 2   62    Male              7.3               4.1                   490
# 3   58    Male              1.0               0.4                   182
# 4   72    Male              3.9               2.0                   195
#
#    Alamine_Aminotransferase  Aspartate_Aminotransferase  Total_Protiens  \
# 0                        16                          18             6.8
# 1                        64                         100             7.5
# 2                        60                          68             7.0
# 3                        14                          20             6.8
# 4                        27                          59             7.3
#
#    Albumin  Albumin_and_Globulin_Ratio  Dataset
# 0      3.3                        0.90        1
# ...

# %%
# Data Cleaning Function
def clean_data(kidney_df):
    # Drop duplicate rows
     kidney_df.drop_duplicates(inplace=True)

# %%
 # Strip column names
kidney_df.columns = kidney_df.columns.str.strip().str.lower()
kidney_df.head()
# Out:
#    age  gender  total_bilirubin  direct_bilirubin  alkaline_phosphotase  \
# 0   65  Female              0.7               0.1                   187
# 1   62    Male             10.9               5.5                   699
# 2   62    Male              7.3               4.1                   490
# 3   58    Male              1.0               0.4                   182
# 4   72    Male              3.9               2.0                   195
#
#    alamine_aminotransferase  aspartate_aminotransferase  total_protiens  \
# 0                        16                          18             6.8
# 1                        64                         100             7.5
# 2                        60                          68             7.0
# 3                        14                          20             6.8
# 4                        27                          59             7.3
#
#    albumin  albumin_and_globulin_ratio  dataset
# 0      3.3                        0.90        1
# ...

# %%
# Handle missing values
liver_df.replace('?', np.nan, inplace=True)
liver_df.fillna(liver_df.median(numeric_only=True), inplace=True)
liver_df.head()
# Out:
#    Age  Gender  Total_Bilirubin  Direct_Bilirubin  Alkaline_Phosphotase  \
# 0   65  Female              0.7               0.1                   187
# 1   62    Male             10.9               5.5                   699
# 2   62    Male              7.3               4.1                   490
# 3   58    Male              1.0               0.4                   182
# 4   72    Male              3.9               2.0                   195
#
#    Alamine_Aminotransferase  Aspartate_Aminotransferase  Total_Protiens  \
# 0                        16                          18             6.8
# 1                        64                         100             7.5
# 2                        60                          68             7.0
# 3                        14                          20             6.8
# 4                        27                          59             7.3
#
#    Albumin  Albumin_and_Globulin_Ratio  Dataset
# 0      3.3                        0.90        1
# ...

# %%
# Data Cleaning Function
def clean_data(liver_df):
    # Drop duplicate rows
     liver_df.drop_duplicates(inplace=True)

# %%
 # Strip column names
liver_df.columns = liver_df.columns.str.strip().str.lower()
liver_df.head()
# Out:
#    age  gender  total_bilirubin  direct_bilirubin  alkaline_phosphotase  \
# 0   65  Female              0.7               0.1                   187
# 1   62    Male             10.9               5.5                   699
# 2   62    Male              7.3               4.1                   490
# 3   58    Male              1.0               0.4                   182
# 4   72    Male              3.9               2.0                   195
#
#    alamine_aminotransferase  aspartate_aminotransferase  total_protiens  \
# 0                        16                          18             6.8
# 1                        64                         100             7.5
# 2                        60                          68             7.0
# 3                        14                          20             6.8
# 4                        27                          59             7.3
#
#    albumin  albumin_and_globulin_ratio  dataset
# 0      3.3                        0.90        1
# ...

# %%
# Handle missing values
parkinsons_df.replace('?', np.nan, inplace=True)
parkinsons_df.fillna(parkinsons_df.median(numeric_only=True), inplace=True)
parkinsons_df.head()
# Out:
#              name  MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# 0  phon_R01_S01_1      119.992       157.302        74.997         0.00784
# 1  phon_R01_S01_2      122.400       148.650       113.819         0.00968
# 2  phon_R01_S01_3      116.682       131.111       111.555         0.01050
# 3  phon_R01_S01_4      116.676       137.871       111.366         0.00997
# 4  phon_R01_S01_5      116.014       141.781       110.655         0.01284
#
#    MDVP:Jitter(Abs)  MDVP:RAP  MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  ...  \
# 0           0.00007   0.00370   0.00554     0.01109       0.04374  ...
# 1           0.00008   0.00465   0.00696     0.01394       0.06134  ...
# 2           0.00009   0.00544   0.00781     0.01633       0.05233  ...
# 3           0.00009   0.00502   0.00698     0.01505       0.05492  ...
# 4           0.00011   0.00655   0.00908     0.01966       0.06425  ...
#
#    Shimmer:DDA      NHR     HNR  status      RPDE       DFA   spread1  \
# ...

# %%
# Data Cleaning Function
def clean_data(liver_df):
    # Drop duplicate rows
     parkinsons_df.drop_duplicates(inplace=True)

# %%
 # Strip column names
parkinsons_df.columns = parkinsons_df.columns.str.strip().str.lower()
parkinsons_df.head()
# Out:
#              name  mdvp:fo(hz)  mdvp:fhi(hz)  mdvp:flo(hz)  mdvp:jitter(%)  \
# 0  phon_R01_S01_1      119.992       157.302        74.997         0.00784
# 1  phon_R01_S01_2      122.400       148.650       113.819         0.00968
# 2  phon_R01_S01_3      116.682       131.111       111.555         0.01050
# 3  phon_R01_S01_4      116.676       137.871       111.366         0.00997
# 4  phon_R01_S01_5      116.014       141.781       110.655         0.01284
#
#    mdvp:jitter(abs)  mdvp:rap  mdvp:ppq  jitter:ddp  mdvp:shimmer  ...  \
# 0           0.00007   0.00370   0.00554     0.01109       0.04374  ...
# 1           0.00008   0.00465   0.00696     0.01394       0.06134  ...
# 2           0.00009   0.00544   0.00781     0.01633       0.05233  ...
# 3           0.00009   0.00502   0.00698     0.01505       0.05492  ...
# 4           0.00011   0.00655   0.00908     0.01966       0.06425  ...
#
#    shimmer:dda      nhr     hnr  status      rpde       dfa   spread1  \
# ...

# %%
# Clean each dataset
liver_df = clean_data(liver_df)
kidney_df = clean_data(kidney_df)
parkinsons_df = clean_data(parkinsons_df)

# %%
print(liver_df)
print(kidney_df)
print(parkinsons_df)
# Out:
# None
# None
# None

# %%
liver_df = pd.read_csv('/content/indian_liver_patient - indian_liver_patient.csv')
kidney_df = pd.read_csv('/content/kidney_disease - kidney_disease.csv/path/to/kidney_data.csv')
parkinsons_df = pd.read_csv('/content/parkinsons - parkinsons.csv')

# %%
liver_df = liver_df[liver_df['column'] > 10]

# %%
liver_df = liver_df[liver_df['column'] > 10]
if liver_df.empty:
    print("Liver DataFrame is empty after filtering.")

# %%
kidney_df = kidney_df[kidney_df['column'] > 10]

# %%
kidney_df = kidney_df[kidney_df['column'] > 10]
if kidney_df.empty:
    print("kidney DataFrame is empty after filtering.")

# %%
parkinsond_df = parkinsons_df[parkinsons_df['column'] > 10]

# %%
parkinsons_df = parkinsons_df[parkinsons_df['column'] > 10]
if parkinsons_df.empty:
    print("parkinsons DataFrame is empty after filtering.")
