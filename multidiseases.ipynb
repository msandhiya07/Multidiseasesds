# %% [markdown]
# <a href="https://colab.research.google.com/github/msandhiya07/Multidiseasesds/blob/main/multidiseases.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Prepocessing data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
k_df=pd.read_csv("/content/kidney_disease - kidney_disease.csv")
k_df.head()
# Out:
#    id   age    bp     sg   al   su     rbc        pc         pcc          ba  \
# 0   0  48.0  80.0  1.020  1.0  0.0     NaN    normal  notpresent  notpresent
# 1   1   7.0  50.0  1.020  4.0  0.0     NaN    normal  notpresent  notpresent
# 2   2  62.0  80.0  1.010  2.0  3.0  normal    normal  notpresent  notpresent
# 3   3  48.0  70.0  1.005  4.0  0.0  normal  abnormal     present  notpresent
# 4   4  51.0  80.0  1.010  2.0  0.0  normal    normal  notpresent  notpresent
#
#    ...  pcv    wc   rc  htn   dm  cad appet   pe  ane classification
# 0  ...   44  7800  5.2  yes  yes   no  good   no   no            ckd
# 1  ...   38  6000  NaN   no   no   no  good   no   no            ckd
# 2  ...   31  7500  NaN   no  yes   no  poor   no  yes            ckd
# 3  ...   32  6700  3.9  yes   no   no  poor  yes  yes            ckd
# 4  ...   35  7300  4.6   no   no   no  good   no   no            ckd
#
# [5 rows x 26 columns]

# %%
l_df=pd.read_csv("/content/indian_liver_patient - indian_liver_patient.csv")
l_df.head()
# Out:
#    Age  Gender  Total_Bilirubin  Direct_Bilirubin  Alkaline_Phosphotase  \
# 0   65  Female              0.7               0.1                   187
# 1   62    Male             10.9               5.5                   699
# 2   62    Male              7.3               4.1                   490
# 3   58    Male              1.0               0.4                   182
# 4   72    Male              3.9               2.0                   195
#
#    Alamine_Aminotransferase  Aspartate_Aminotransferase  Total_Protiens  \
# 0                        16                          18             6.8
# 1                        64                         100             7.5
# 2                        60                          68             7.0
# 3                        14                          20             6.8
# 4                        27                          59             7.3
#
#    Albumin  Albumin_and_Globulin_Ratio  Dataset
# 0      3.3                        0.90        1
# ...

# %%
p_df=pd.read_csv("/content/parkinsons - parkinsons.csv")
p_df.head()
# Out:
#              name  MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# 0  phon_R01_S01_1      119.992       157.302        74.997         0.00784
# 1  phon_R01_S01_2      122.400       148.650       113.819         0.00968
# 2  phon_R01_S01_3      116.682       131.111       111.555         0.01050
# 3  phon_R01_S01_4      116.676       137.871       111.366         0.00997
# 4  phon_R01_S01_5      116.014       141.781       110.655         0.01284
#
#    MDVP:Jitter(Abs)  MDVP:RAP  MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  ...  \
# 0           0.00007   0.00370   0.00554     0.01109       0.04374  ...
# 1           0.00008   0.00465   0.00696     0.01394       0.06134  ...
# 2           0.00009   0.00544   0.00781     0.01633       0.05233  ...
# 3           0.00009   0.00502   0.00698     0.01505       0.05492  ...
# 4           0.00011   0.00655   0.00908     0.01966       0.06425  ...
#
#    Shimmer:DDA      NHR     HNR  status      RPDE       DFA   spread1  \
# ...

# %%
k_df.shape
# Out:
# (400, 26)

# %%
l_df.shape
# Out:
# (583, 11)

# %%
p_df.shape
# Out:
# (195, 24)

# %%
k_df.describe()
# Out:
#                id         age          bp          sg          al          su  \
# count  400.000000  391.000000  388.000000  353.000000  354.000000  351.000000
# mean   199.500000   51.483376   76.469072    1.017408    1.016949    0.450142
# std    115.614301   17.169714   13.683637    0.005717    1.352679    1.099191
# min      0.000000    2.000000   50.000000    1.005000    0.000000    0.000000
# 25%     99.750000   42.000000   70.000000    1.010000    0.000000    0.000000
# 50%    199.500000   55.000000   80.000000    1.020000    0.000000    0.000000
# 75%    299.250000   64.500000   80.000000    1.020000    2.000000    0.000000
# max    399.000000   90.000000  180.000000    1.025000    5.000000    5.000000
#
#               bgr          bu          sc         sod         pot        hemo
# count  356.000000  381.000000  383.000000  313.000000  312.000000  348.000000
# mean   148.036517   57.425722    3.072454  137.528754    4.627244   12.526437
# ...

# %%
l_df.describe()
# Out:
#               Age  Total_Bilirubin  Direct_Bilirubin  Alkaline_Phosphotase  \
# count  583.000000       583.000000        583.000000            583.000000
# mean    44.746141         3.298799          1.486106            290.576329
# std     16.189833         6.209522          2.808498            242.937989
# min      4.000000         0.400000          0.100000             63.000000
# 25%     33.000000         0.800000          0.200000            175.500000
# 50%     45.000000         1.000000          0.300000            208.000000
# 75%     58.000000         2.600000          1.300000            298.000000
# max     90.000000        75.000000         19.700000           2110.000000
#
#        Alamine_Aminotransferase  Aspartate_Aminotransferase  Total_Protiens  \
# count                583.000000                  583.000000      583.000000
# mean                  80.713551                  109.910806        6.483190
# ...

# %%
p_df.describe()
# Out:
#        MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# count   195.000000    195.000000    195.000000      195.000000
# mean    154.228641    197.104918    116.324631        0.006220
# std      41.390065     91.491548     43.521413        0.004848
# min      88.333000    102.145000     65.476000        0.001680
# 25%     117.572000    134.862500     84.291000        0.003460
# 50%     148.790000    175.829000    104.315000        0.004940
# 75%     182.769000    224.205500    140.018500        0.007365
# max     260.105000    592.030000    239.170000        0.033160
#
#        MDVP:Jitter(Abs)    MDVP:RAP    MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  \
# count        195.000000  195.000000  195.000000  195.000000    195.000000
# mean           0.000044    0.003306    0.003446    0.009920      0.029709
# std            0.000035    0.002968    0.002759    0.008903      0.018857
# min            0.000007    0.000680    0.000920    0.002040      0.009540
# ...

# %%
k_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 26 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id              400 non-null    int64
#  1   age             391 non-null    float64
#  2   bp              388 non-null    float64
#  3   sg              353 non-null    float64
#  4   al              354 non-null    float64
#  5   su              351 non-null    float64
#  6   rbc             248 non-null    object
#  7   pc              335 non-null    object
#  8   pcc             396 non-null    object
#  9   ba              396 non-null    object
#  10  bgr             356 non-null    float64
#  11  bu              381 non-null    float64
#  12  sc              383 non-null    float64
#  13  sod             313 non-null    float64
#  14  pot             312 non-null    float64
#  15  hemo            348 non-null    float64
#  16  pcv             330 non-null    object
# ...

# %%
p_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 24 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   name              195 non-null    object
#  1   MDVP:Fo(Hz)       195 non-null    float64
#  2   MDVP:Fhi(Hz)      195 non-null    float64
#  3   MDVP:Flo(Hz)      195 non-null    float64
#  4   MDVP:Jitter(%)    195 non-null    float64
#  5   MDVP:Jitter(Abs)  195 non-null    float64
#  6   MDVP:RAP          195 non-null    float64
#  7   MDVP:PPQ          195 non-null    float64
#  8   Jitter:DDP        195 non-null    float64
#  9   MDVP:Shimmer      195 non-null    float64
#  10  MDVP:Shimmer(dB)  195 non-null    float64
#  11  Shimmer:APQ3      195 non-null    float64
#  12  Shimmer:APQ5      195 non-null    float64
#  13  MDVP:APQ          195 non-null    float64
#  14  Shimmer:DDA       195 non-null    float64
#  15  NHR               195 non-null    float64
# ...

# %%
k_df.head()
# Out:
#    id   age    bp     sg   al   su     rbc        pc         pcc          ba  \
# 0   0  48.0  80.0  1.020  1.0  0.0     NaN    normal  notpresent  notpresent
# 1   1   7.0  50.0  1.020  4.0  0.0     NaN    normal  notpresent  notpresent
# 2   2  62.0  80.0  1.010  2.0  3.0  normal    normal  notpresent  notpresent
# 3   3  48.0  70.0  1.005  4.0  0.0  normal  abnormal     present  notpresent
# 4   4  51.0  80.0  1.010  2.0  0.0  normal    normal  notpresent  notpresent
#
#    ...  pcv    wc   rc  htn   dm  cad appet   pe  ane classification
# 0  ...   44  7800  5.2  yes  yes   no  good   no   no            ckd
# 1  ...   38  6000  NaN   no   no   no  good   no   no            ckd
# 2  ...   31  7500  NaN   no  yes   no  poor   no  yes            ckd
# 3  ...   32  6700  3.9  yes   no   no  poor  yes  yes            ckd
# 4  ...   35  7300  4.6   no   no   no  good   no   no            ckd
#
# [5 rows x 26 columns]

# %%
k_df.drop('id',axis=1,inplace=True)

# %%
k_df.head(7)
# Out:
#     age    bp     sg   al   su     rbc        pc         pcc          ba  \
# 0  48.0  80.0  1.020  1.0  0.0     NaN    normal  notpresent  notpresent
# 1   7.0  50.0  1.020  4.0  0.0     NaN    normal  notpresent  notpresent
# 2  62.0  80.0  1.010  2.0  3.0  normal    normal  notpresent  notpresent
# 3  48.0  70.0  1.005  4.0  0.0  normal  abnormal     present  notpresent
# 4  51.0  80.0  1.010  2.0  0.0  normal    normal  notpresent  notpresent
# 5  60.0  90.0  1.015  3.0  0.0     NaN       NaN  notpresent  notpresent
# 6  68.0  70.0  1.010  0.0  0.0     NaN    normal  notpresent  notpresent
#
#      bgr  ...  pcv    wc   rc  htn   dm cad appet   pe  ane classification
# 0  121.0  ...   44  7800  5.2  yes  yes  no  good   no   no            ckd
# 1    NaN  ...   38  6000  NaN   no   no  no  good   no   no            ckd
# 2  423.0  ...   31  7500  NaN   no  yes  no  poor   no  yes            ckd
# 3  117.0  ...   32  6700  3.9  yes   no  no  poor  yes  yes            ckd
# ...

# %%
k_df.columns=['age','blood_pressure','specific_gravity','albumin','sugar','red_blood_cells','pus_cells','pus_cell_clumps','bacteria',
'blood_glucose_random','blood_urea','serum creatinine','sodium','potassium','hemoglobin',
'packed_cell_volume','white_blood_cell_count','red_blood_cell_count','hypertension','diabetes_mellitus',
'coronary_artery_disease','appetite','pedal_edema','anemia','classification']

# %%
k_df.head(4)
# Out:
#     age  blood_pressure  specific_gravity  albumin  sugar red_blood_cells  \
# 0  48.0            80.0             1.020      1.0    0.0             NaN
# 1   7.0            50.0             1.020      4.0    0.0             NaN
# 2  62.0            80.0             1.010      2.0    3.0          normal
# 3  48.0            70.0             1.005      4.0    0.0          normal
#
#   pus_cells pus_cell_clumps    bacteria  blood_glucose_random  ...  \
# 0    normal      notpresent  notpresent                 121.0  ...
# 1    normal      notpresent  notpresent                   NaN  ...
# 2    normal      notpresent  notpresent                 423.0  ...
# 3  abnormal         present  notpresent                 117.0  ...
#
#    packed_cell_volume  white_blood_cell_count  red_blood_cell_count  \
# 0                  44                    7800                   5.2
# 1                  38                    6000                   NaN
# ...

# %%
text_columns=['red_blood_cell_count','packed_cell_volume','white_blood_cell_count']
for i in text_columns:
  print(f"{i} : {k_df[i].dtype}")
# Out:
# red_blood_cell_count : object
# packed_cell_volume : object
# white_blood_cell_count : object

# %%
def convert_text_to_numeric(k_df, column):
    k_df[column] = pd.to_numeric(k_df[column], errors="coerce")

for column in text_columns:
    convert_text_to_numeric(k_df, column)
    print(f"{column}: {k_df[column].dtypes}")
# Out:
# red_blood_cell_count: float64
# packed_cell_volume: float64
# white_blood_cell_count: float64

# %%
missing=k_df.isnull().sum()
missing[missing>0].sort_values(ascending=False).head(20)
# Out:
# red_blood_cells           152
# red_blood_cell_count      131
# white_blood_cell_count    106
# potassium                  88
# sodium                     87
# packed_cell_volume         71
# pus_cells                  65
# hemoglobin                 52
# sugar                      49
# specific_gravity           47
# albumin                    46
# blood_glucose_random       44
# blood_urea                 19
# serum creatinine           17
# blood_pressure             12
# age                         9
# bacteria                    4
# pus_cell_clumps             4
# hypertension                2
# diabetes_mellitus           2
# dtype: int64

# %%
def mean_inputation(k_df,column):
  mean=k_df[column].mean()
  k_df[column].fillna(value=mean_value,inplace=True)

def mode_inputation(k_df,column):
  mode=k_df[column].mode()[0]
  k_df[column].k_df[column].fillna(mode)

# %%
def mean_value_imputation(df, column):
    mean_value = df[column].mean()
    df[column].fillna(mean_value, inplace=True)

# Select numeric columns
num_cols = [col for col in k_df.columns if k_df[col].dtype != 'object']

# Apply mean imputation to each numeric column
for col_name in num_cols:
    mean_value_imputation(k_df, col_name)
    print(f"{col_name}: Imputation done")
# Out:
# age: Imputation done
# blood_pressure: Imputation done
# specific_gravity: Imputation done
# albumin: Imputation done
# sugar: Imputation done
# blood_glucose_random: Imputation done
# blood_urea: Imputation done
# serum creatinine: Imputation done
# sodium: Imputation done
# potassium: Imputation done
# hemoglobin: Imputation done
# packed_cell_volume: Imputation done
# white_blood_cell_count: Imputation done
# red_blood_cell_count: Imputation done
# <ipython-input-24-2df33e347dc6>:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# ...

# %%
# Define mode imputation function
def mode_value_imputation(df, column):
    mode_value = df[column].mode()[0]  # Get the most frequent value (mode)
    df[column].fillna(mode_value, inplace=True)

# Identify categorical columns
cat_cols = [col for col in k_df.columns if k_df[col].dtype == 'object']

# Apply mode imputation to each categorical column
for col_name in cat_cols:
    mode_value_imputation(k_df, col_name)
    print(f"{col_name}: Mode imputation done")
# Out:
# red_blood_cells: Mode imputation done
# pus_cells: Mode imputation done
# pus_cell_clumps: Mode imputation done
# bacteria: Mode imputation done
# hypertension: Mode imputation done
# diabetes_mellitus: Mode imputation done
# coronary_artery_disease: Mode imputation done
# appetite: Mode imputation done
# pedal_edema: Mode imputation done
# anemia: Mode imputation done
# classification: Mode imputation done
# <ipython-input-25-15c7df3ab924>:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
# ...

# %%
missing =k_df.isnull().sum()
missing[missing>0].sort_values(ascending=False).head(20)
# Out:
# Series([], dtype: int64)

# %%
k_df.head()
# Out:
#     age  blood_pressure  specific_gravity  albumin  sugar red_blood_cells  \
# 0  48.0            80.0             1.020      1.0    0.0          normal
# 1   7.0            50.0             1.020      4.0    0.0          normal
# 2  62.0            80.0             1.010      2.0    3.0          normal
# 3  48.0            70.0             1.005      4.0    0.0          normal
# 4  51.0            80.0             1.010      2.0    0.0          normal
#
#   pus_cells pus_cell_clumps    bacteria  blood_glucose_random  ...  \
# 0    normal      notpresent  notpresent            121.000000  ...
# 1    normal      notpresent  notpresent            148.036517  ...
# 2    normal      notpresent  notpresent            423.000000  ...
# 3  abnormal         present  notpresent            117.000000  ...
# 4    normal      notpresent  notpresent            106.000000  ...
#
#    packed_cell_volume  white_blood_cell_count  red_blood_cell_count  \
# ...

# %%
print(f"diabetes_mellitus:{k_df['diabetes_mellitus'].unique()}")
print(f"coronary_artery_disease:{k_df['coronary_artery_disease'].unique()}")
print(f"classification:{k_df['classification'].unique()}")
# Out:
# diabetes_mellitus:['yes' 'no']
# coronary_artery_disease:['no' 'yes']
# classification:['ckd' 'notckd']

# %%
# Define mapping for categorical columns
categorical_mappings = {
    'classification': {'ckd': 1, 'notckd': 0},
    'hypertension': {'yes': 1, 'no': 0},
    'diabetes_mellitus': {'yes': 1, 'no': 0},
    'coronary_artery_disease': {'yes': 1, 'no': 0},
    'appetite': {'good': 1, 'poor': 0},
    'pedal_edema': {'yes': 1, 'no': 0},
    'anemia': {'yes': 1, 'no': 0}
}

# Apply mapping to each categorical column
for col, mapping in categorical_mappings.items():
    k_df[col] = k_df[col].map(mapping)
    print(f"{col}: {k_df[col].unique()}")
# Out:
# classification: [1 0]
# hypertension: [1 0]
# diabetes_mellitus: [1 0]
# coronary_artery_disease: [0 1]
# appetite: [1 0]
# pedal_edema: [0 1]
# anemia: [0 1]

# %%
k_df.head(4)
# Out:
#     age  blood_pressure  specific_gravity  albumin  sugar red_blood_cells  \
# 0  48.0            80.0             1.020      1.0    0.0          normal
# 1   7.0            50.0             1.020      4.0    0.0          normal
# 2  62.0            80.0             1.010      2.0    3.0          normal
# 3  48.0            70.0             1.005      4.0    0.0          normal
#
#   pus_cells pus_cell_clumps    bacteria  blood_glucose_random  ...  \
# 0    normal      notpresent  notpresent            121.000000  ...
# 1    normal      notpresent  notpresent            148.036517  ...
# 2    normal      notpresent  notpresent            423.000000  ...
# 3  abnormal         present  notpresent            117.000000  ...
#
#    packed_cell_volume  white_blood_cell_count  red_blood_cell_count  \
# 0                44.0                  7800.0              5.200000
# 1                38.0                  6000.0              4.707435
# ...

# %%
# Convert categorical columns to numeric
categorical_columns = k_df.select_dtypes(include='object').columns

for col in categorical_columns:
    k_df[col] = k_df[col].astype('category').cat.codes  # Converts to category and assigns numeric codes

# Now plot correlation
plt.figure(figsize=(15, 8))
sns.heatmap(k_df.corr(), annot=True, linewidths=0.5, cmap='coolwarm')
plt.show()

# %%
target_corr=k_df.corr()['classification'].abs().sort_values(ascending=False)[1:]
target_corr
# Out:
# hemoglobin                 0.729628
# specific_gravity           0.698957
# packed_cell_volume         0.690060
# albumin                    0.599238
# red_blood_cell_count       0.590913
# hypertension               0.590438
# diabetes_mellitus          0.559060
# blood_glucose_random       0.401374
# appetite                   0.393341
# pus_cells                  0.375154
# pedal_edema                0.375154
# blood_urea                 0.372033
# sodium                     0.342288
# sugar                      0.327812
# anemia                     0.325396
# serum creatinine           0.294079
# blood_pressure             0.290600
# red_blood_cells            0.282642
# pus_cell_clumps            0.265313
# coronary_artery_disease    0.236088
# age                        0.225405
# white_blood_cell_count     0.205274
# bacteria                   0.186871
# potassium                  0.076921
# Name: classification, dtype: float64

# %%
k_df['classification'].value_counts()
# Out:
# classification
# 1    250
# 0    150
# Name: count, dtype: int64

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from sklearn.metrics import accuracy_score, classification_report


# Select 5 features and the target
selected_features = ["age", "blood_pressure", "specific_gravity", "albumin", "sugar"]  # Replace with desired features
x = k_df[selected_features]
y = k_df["classification"]  # Target variable

# Train-test split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.25, random_state=10)


# Train XGBoost
xgb_model = XGBClassifier(use_label_encoder=False, eval_metric="logloss", random_state=10)
xgb_model.fit(x_train, y_train)

# Make predictions
xgb_predictions = xgb_model.predict(x_test)

# Evaluate XGBoost
print("XGBoost Results:")
print(f"Accuracy: {accuracy_score(y_test, xgb_predictions):.2f}")
print("Classification Report:")
print(classification_report(y_test, xgb_predictions))
# Out:
# XGBoost Results:
# Accuracy: 0.95
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.94      0.91      0.92        32
#            1       0.96      0.97      0.96        68
#
#     accuracy                           0.95       100
#    macro avg       0.95      0.94      0.94       100
# weighted avg       0.95      0.95      0.95       100
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [08:00:47] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)

# %%
# Save the XGBoost model
with open("kidney_xgboost_model.pkl", "wb") as xgb_file:
    pickle.dump(xgb_model, xgb_file)

print("Models saved successfully!")
# Out:
# Models saved successfully!

# %%
# Select 5 features and the target
selected_features = ["age", "blood_pressure", "specific_gravity", "albumin", "sugar"]  # Replace with desired features
x = k_df[selected_features]
y = k_df["classification"]  # Target variable

# Train-test split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.25, random_state=10)

# Train Random Forest
rf_model = RandomForestClassifier(random_state=10)
rf_model.fit(x_train, y_train)

# Make predictions
rf_predictions = rf_model.predict(x_test)
xgb_predictions = xgb_model.predict(x_test)

# Evaluate Random Forest
print("Random Forest Results:")
print(f"Accuracy: {accuracy_score(y_test, rf_predictions):.2f}")
print("Classification Report:")
print(classification_report(y_test, rf_predictions))
# Out:
# Random Forest Results:
# Accuracy: 0.95
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.94      0.91      0.92        32
#            1       0.96      0.97      0.96        68
#
#     accuracy                           0.95       100
#    macro avg       0.95      0.94      0.94       100
# weighted avg       0.95      0.95      0.95       100

# %%
# Save the Random Forest model
with open("kidney_random_forest.pkl", "wb") as rf_file:
    pickle.dump(rf_model, rf_file)

print("Models saved successfully!")
# Out:
# Models saved successfully!

# %%
#liver dataset
l_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 583 entries, 0 to 582
# Data columns (total 11 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Age                         583 non-null    int64
#  1   Gender                      583 non-null    object
#  2   Total_Bilirubin             583 non-null    float64
#  3   Direct_Bilirubin            583 non-null    float64
#  4   Alkaline_Phosphotase        583 non-null    int64
#  5   Alamine_Aminotransferase    583 non-null    int64
#  6   Aspartate_Aminotransferase  583 non-null    int64
#  7   Total_Protiens              583 non-null    float64
#  8   Albumin                     583 non-null    float64
#  9   Albumin_and_Globulin_Ratio  579 non-null    float64
#  10  Dataset                     583 non-null    int64
# dtypes: float64(5), int64(5), object(1)
# memory usage: 50.2+ KB

# %%
l_df.head()
# Out:
#    Age  Gender  Total_Bilirubin  Direct_Bilirubin  Alkaline_Phosphotase  \
# 0   65  Female              0.7               0.1                   187
# 1   62    Male             10.9               5.5                   699
# 2   62    Male              7.3               4.1                   490
# 3   58    Male              1.0               0.4                   182
# 4   72    Male              3.9               2.0                   195
#
#    Alamine_Aminotransferase  Aspartate_Aminotransferase  Total_Protiens  \
# 0                        16                          18             6.8
# 1                        64                         100             7.5
# 2                        60                          68             7.0
# 3                        14                          20             6.8
# 4                        27                          59             7.3
#
#    Albumin  Albumin_and_Globulin_Ratio  Dataset
# 0      3.3                        0.90        1
# ...

# %%
text_columns=['Alkaline_Phosphotase','Alamine_Aminotransferase','Aspartate_Aminotransferase']
for i in text_columns:
  print(f"{i} : {l_df[i].dtype}")
# Out:
# Alkaline_Phosphotase : int64
# Alamine_Aminotransferase : int64
# Aspartate_Aminotransferase : int64

# %%
missing=l_df.isnull().sum()
missing[missing>0].sort_values(ascending=False).head(20)
# Out:
# Albumin_and_Globulin_Ratio    4
# dtype: int64

# %%
def mean_inputation(k_df,column):
  mean=l_df[column].mean()
  l_df[column].fillna(value=mean_value,inplace=True)
def mode_inputation(k_df,column):
  mode=l_df[column].mode()[0]
  l_df[column].l_df[column].fillna(mode)

# %%
def mean_value_imputation(df, column):
    mean_value = df[column].mean()
    df[column].fillna(mean_value, inplace=True)

# %%
# Select numeric columns
num_cols = [col for col in l_df.columns if l_df[col].dtype != 'object']

# %%
# Apply mean imputation to each numeric column
for col_name in num_cols:
    mean_value_imputation(l_df, col_name)
    print(f"{col_name}: Imputation done")
# Out:
# Age: Imputation done
# Total_Bilirubin: Imputation done
# Direct_Bilirubin: Imputation done
# Alkaline_Phosphotase: Imputation done
# Alamine_Aminotransferase: Imputation done
# Aspartate_Aminotransferase: Imputation done
# Total_Protiens: Imputation done
# Albumin: Imputation done
# Albumin_and_Globulin_Ratio: Imputation done
# Dataset: Imputation done
# <ipython-input-43-358c13626c6c>:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[column].fillna(mean_value, inplace=True)

# %%
# Define mode imputation function
def mode_value_imputation(df, column):
    mode_value = df[column].mode()[0]  # Get the most frequent value (mode)
    df[column].fillna(mode_value, inplace=True)

# %%
cat_cols = [col for col in l_df.columns if l_df[col].dtype == 'object']

# %%
# Apply mode imputation to each categorical column
for col_name in cat_cols:
    mode_value_imputation(l_df, col_name)
    print(f"{col_name}: Mode imputation done")
# Out:
# Gender: Mode imputation done
# <ipython-input-46-7168d47c0677>:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[column].fillna(mode_value, inplace=True)

# %%
missing =l_df.isnull().sum()
missing[missing>0].sort_values(ascending=False).head(20)
# Out:
# Series([], dtype: int64)

# %%
print(f"Age:{l_df['Age'].unique()}")
print(f"Gender:{l_df['Gender'].unique()}")
print(f"Total_Bilirubin:{l_df['Total_Bilirubin'].unique()}")
print(f"Direct_Bilirubin:{l_df['Direct_Bilirubin'].unique()}")
# Out:
# Age:[65 62 58 72 46 26 29 17 55 57 64 74 61 25 38 33 40 51 63 34 20 84 52 30
#  48 47 45 42 50 85 35 21 32 31 54 37 66 60 19 75 68 70 49 14 13 18 39 27
#  36 24 28 53 15 56 44 41  7 22  8  6  4 43 23 12 69 16 78 11 73 67 10 90]
# Gender:['Female' 'Male']
# Total_Bilirubin:[ 0.7 10.9  7.3  1.   3.9  1.8  0.9  0.6  2.7  1.1  1.6  2.2  2.9  6.8
#   1.9  4.1  6.2  4.   2.6  1.3 14.2  1.4  2.4 18.4  3.1  8.9  0.8  2.8
#   2.   5.7  8.6  5.8  5.2  3.8  6.6  0.5  5.3  3.2  1.2 12.7 15.9 18.
#  23.  22.7  1.7  3.  11.3  4.7  4.2  3.5  5.9  8.7 11.  11.5  4.5 75.
#  22.8 14.1 14.8 10.6  8.   1.5  2.1  6.3  2.3 27.2  2.5  3.6 30.5 16.4
#  14.5 18.5 23.2  3.7  3.3  7.1  6.7 22.6  7.5  5.   4.9  8.2  0.4  7.4
#  23.3  7.9  3.4 19.8 32.6 17.7 20.  26.3  4.4  9.4 30.8 19.6 15.8  5.5
#  20.2 27.7 11.1 10.2 42.8 15.2 16.6 17.3 22.5 16.7  7.7 15.6 12.1 25.
#  15. ]
# Direct_Bilirubin:[ 0.1  5.5  4.1  0.4  2.   0.7  0.2  0.3  1.3  0.8  0.5  1.   3.   1.9
# ...

# %%
# Define mapping for categorical columns
categorical_mappings = {
    'classification': {'ckd': 1, 'notckd': 0},
    'hypertension': {'yes': 1, 'no': 0},
    'diabetes_mellitus': {'yes': 1, 'no': 0},
    'coronary_artery_disease': {'yes': 1, 'no': 0},
    'appetite': {'good': 1, 'poor': 0},
    'pedal_edema': {'yes': 1, 'no': 0},
    'anemia': {'yes': 1, 'no': 0}
}

# %%
# Mapping liver dataset columns to kidney dataset naming
column_mapping = {
    'Age': 'age',
    'Gender': 'gender',
    'Total_Bilirubin': 'total_bilirubin',
    'Direct_Bilirubin': 'direct_bilirubin',
    'Alkaline_Phosphotase': 'alkaline_phosphotase',
    'Alamine_Aminotransferase': 'alamine_aminotransferase',
    'Aspartate_Aminotransferase': 'aspartate_aminotransferase',
    'Total_Protiens': 'total_proteins',
    'Albumin': 'albumin',
    'Albumin_and_Globulin_Ratio': 'albumin_and_globulin_ratio',
    'Dataset': 'dataset'
}

# %%
# Rename the columns in the liver dataset to match the kidney dataset columns
l_df = l_df.rename(columns=column_mapping)

# %%
# For each column that has categorical mappings, apply the transformation
for column, mapping in categorical_mappings.items():
    if column in l_df.columns:
        l_df[column] = l_df[column].map(mapping)

print(l_df.head())
# Out:
#    age  gender  total_bilirubin  direct_bilirubin  alkaline_phosphotase  \
# 0   65  Female              0.7               0.1                   187
# 1   62    Male             10.9               5.5                   699
# 2   62    Male              7.3               4.1                   490
# 3   58    Male              1.0               0.4                   182
# 4   72    Male              3.9               2.0                   195
#
#    alamine_aminotransferase  aspartate_aminotransferase  total_proteins  \
# 0                        16                          18             6.8
# 1                        64                         100             7.5
# 2                        60                          68             7.0
# 3                        14                          20             6.8
# 4                        27                          59             7.3
#
#    albumin  albumin_and_globulin_ratio  dataset
# 0      3.3                        0.90        1
# ...

# %%
l_df.describe(include=['object'])
# Out:
#        gender
# count     583
# unique      2
# top      Male
# freq      441

# %%
#bar plots for categorical features
plt.figure(figsize=(5,5))
sns.countplot(y='gender',data=l_df)
# Out:
# <Axes: xlabel='count', ylabel='gender'>

# %%
l_df[l_df['gender']=='Male'][['dataset','gender']].head()
# Out:
#    dataset gender
# 1        1   Male
# 2        1   Male
# 3        1   Male
# 4        1   Male
# 5        1   Male

# %%
sns.catplot(x='age', y='gender', hue='dataset', data=l_df)

# %%
l_df['gender'].value_counts()
# Out:
# gender
# Male      441
# Female    142
# Name: count, dtype: int64

# %%
#categorical calue handling
def convertgender(x):
    if x== 'Male':
        return 0
    else:
     return 1
l_df['gender']=l_df['gender'].map(convertgender)

# %%
l_df.head()
# Out:
#    age  gender  total_bilirubin  direct_bilirubin  alkaline_phosphotase  \
# 0   65       1              0.7               0.1                   187
# 1   62       0             10.9               5.5                   699
# 2   62       0              7.3               4.1                   490
# 3   58       0              1.0               0.4                   182
# 4   72       0              3.9               2.0                   195
#
#    alamine_aminotransferase  aspartate_aminotransferase  total_proteins  \
# 0                        16                          18             6.8
# 1                        64                         100             7.5
# 2                        60                          68             7.0
# 3                        14                          20             6.8
# 4                        27                          59             7.3
#
#    albumin  albumin_and_globulin_ratio  dataset
# 0      3.3                        0.90        1
# ...

# %%
l_df.corr()
# Out:
#                                  age    gender  total_bilirubin  \
# age                         1.000000 -0.056560         0.011763
# gender                     -0.056560  1.000000        -0.089291
# total_bilirubin             0.011763 -0.089291         1.000000
# direct_bilirubin            0.007529 -0.100436         0.874618
# alkaline_phosphotase        0.080425  0.027496         0.206669
# alamine_aminotransferase   -0.086883 -0.082332         0.214065
# aspartate_aminotransferase -0.019910 -0.080336         0.237831
# total_proteins             -0.187461  0.089121        -0.008099
# albumin                    -0.265924  0.093799        -0.222250
# albumin_and_globulin_ratio -0.216089  0.003404        -0.206159
# dataset                    -0.137351  0.082416        -0.220208
#
#                             direct_bilirubin  alkaline_phosphotase  \
# age                                 0.007529              0.080425
# ...

# %%
#Positive Correlation-> one feature increases other alse increases
#Negative Correlation-> one feature increases other alse decreases
#closer to 0-> waek relationship
plt.figure(figsize=(10, 10))
sns.heatmap(l_df.corr())
# Out:
# <Axes: >

# %%
mask=np.zeros_like(l_df.corr())
mask[np.triu_indices_from(mask)]=True
plt.figure(figsize=(10, 10))
sns.heatmap(l_df.corr()*100,annot=True,mask=mask,cmap='coolwarm')
# Out:
# <Axes: >

# %%
l_df=l_df.drop_duplicates()
l_df.shape
# Out:
# (570, 11)

# %%
l_df.isnull().sum()
# Out:
# age                           0
# gender                        0
# total_bilirubin               0
# direct_bilirubin              0
# alkaline_phosphotase          0
# alamine_aminotransferase      0
# aspartate_aminotransferase    0
# total_proteins                0
# albumin                       0
# albumin_and_globulin_ratio    0
# dataset                       0
# dtype: int64

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from sklearn.metrics import accuracy_score, classification_report

# Select features and target
selected_features = [
   	"age","gender","total_bilirubin","total_proteins","albumin"
]
x = l_df[selected_features]  # Features
y = l_df["dataset"]          # Target variable

l_df["gender"] = l_df["gender"].map({"Male": 0, "Female": 1})

# Train-test split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.25, random_state=10)

# Train Random Forest model
rf_model = RandomForestClassifier(random_state=10)
rf_model.fit(x_train, y_train)

# Predictions
rf_predictions = rf_model.predict(x_test)


# Evaluate Random Forest
print("Random Forest Results:")
print(f"Accuracy: {accuracy_score(y_test, rf_predictions):.2f}")
print("Classification Report:")
print(classification_report(y_test, rf_predictions))
# Out:
# <ipython-input-72-855d5cf424a4>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   l_df["gender"] = l_df["gender"].map({"Male": 0, "Female": 1})
# Random Forest Results:
# Accuracy: 0.66
# Classification Report:
#               precision    recall  f1-score   support
#
#            1       0.76      0.81      0.78       108
#            2       0.28      0.23      0.25        35
#
#     accuracy                           0.66       143
#    macro avg       0.52      0.52      0.52       143
# weighted avg       0.64      0.66      0.65       143

# %%
import pickle

# Save the Random Forest model
with open("liver_random_forest.pkl", "wb") as rf_file:
    pickle.dump(rf_model, rf_file)

print("Models saved successfully!")
# Out:
# Models saved successfully!

# %%
_#parkinsons
p_df.head()
# Out:
#              name  MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# 0  phon_R01_S01_1      119.992       157.302        74.997         0.00784
# 1  phon_R01_S01_2      122.400       148.650       113.819         0.00968
# 2  phon_R01_S01_3      116.682       131.111       111.555         0.01050
# 3  phon_R01_S01_4      116.676       137.871       111.366         0.00997
# 4  phon_R01_S01_5      116.014       141.781       110.655         0.01284
#
#    MDVP:Jitter(Abs)  MDVP:RAP  MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  ...  \
# 0           0.00007   0.00370   0.00554     0.01109       0.04374  ...
# 1           0.00008   0.00465   0.00696     0.01394       0.06134  ...
# 2           0.00009   0.00544   0.00781     0.01633       0.05233  ...
# 3           0.00009   0.00502   0.00698     0.01505       0.05492  ...
# 4           0.00011   0.00655   0.00908     0.01966       0.06425  ...
#
#    Shimmer:DDA      NHR     HNR  status      RPDE       DFA   spread1  \
# ...

# %%
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# %%
p_df= pd.read_csv('/content/parkinsons - parkinsons.csv')

# %%
print(p_df.head())
print(p_df.info())
# Out:
#              name  MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# 0  phon_R01_S01_1      119.992       157.302        74.997         0.00784
# 1  phon_R01_S01_2      122.400       148.650       113.819         0.00968
# 2  phon_R01_S01_3      116.682       131.111       111.555         0.01050
# 3  phon_R01_S01_4      116.676       137.871       111.366         0.00997
# 4  phon_R01_S01_5      116.014       141.781       110.655         0.01284
#
#    MDVP:Jitter(Abs)  MDVP:RAP  MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  ...  \
# 0           0.00007   0.00370   0.00554     0.01109       0.04374  ...
# 1           0.00008   0.00465   0.00696     0.01394       0.06134  ...
# 2           0.00009   0.00544   0.00781     0.01633       0.05233  ...
# 3           0.00009   0.00502   0.00698     0.01505       0.05492  ...
# 4           0.00011   0.00655   0.00908     0.01966       0.06425  ...
#
#    Shimmer:DDA      NHR     HNR  status      RPDE       DFA   spread1  \
# ...

# %%
X = p_df.drop(['status', 'name'], axis=1)
y = p_df['status']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)

# %%
rf_model = RandomForestClassifier(n_estimators=100, random_state=42)
rf_model.fit(X_train, y_train)
y_pred_rf = rf_model.predict(X_test)

# %%
from xgboost import XGBClassifier

# Remove the 'use_label_encoder' parameter, as it's not needed in the latest versions of XGBoost
xgb_model = XGBClassifier(eval_metric='logloss')
xgb_model.fit(X_train, y_train)

# Make predictions and calculate accuracy for XGBoost
y_pred_xgb = xgb_model.predict(X_test)

# Accuracy for XGBoost
xgb_accuracy = accuracy_score(y_test, y_pred_xgb)
print(f"XGBoost Accuracy: {xgb_accuracy:.2f}")

# Classification Report and Confusion Matrix for XGBoost
print("XGBoost Classification Report:\n", classification_report(y_test, y_pred_xgb))
print("XGBoost Confusion Matrix:\n", confusion_matrix(y_test, y_pred_xgb))
# Out:
# XGBoost Accuracy: 0.92
# XGBoost Classification Report:
#                precision    recall  f1-score   support
#
#            0       1.00      0.64      0.78        11
#            1       0.90      1.00      0.95        38
#
#     accuracy                           0.92        49
#    macro avg       0.95      0.82      0.86        49
# weighted avg       0.93      0.92      0.91        49
#
# XGBoost Confusion Matrix:
#  [[ 7  4]
#  [ 0 38]]

# %%
import pickle as pkl
with open('parkinxg.pkl', 'wb') as file:
  pkl.dump(rf_model, file)

# %%
rf_accuracy = accuracy_score(y_test, y_pred_rf)
print(f"Random Forest Accuracy: {rf_accuracy:.2f}")
# Out:
# Random Forest Accuracy: 0.94

# %%
import pickle as pkl
with open('parkinrandom.pkl', 'wb') as file:
    pkl.dump(xgb_model, file)
